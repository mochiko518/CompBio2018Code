# %%
# プロット
plt.figure( figsize=(5, 5), dpi=120)
plt.matshow(data, cmap=plt.cm.gray, fignum=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3da9a0470747> in <module>()
#       1 # プロット
# ----> 2 plt.figure( figsize=(5, 5), dpi=120)
#       3 plt.matshow(data, cmap=plt.cm.gray, fignum=1)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# データの読み込み
data = np.genfromtxt("./CA.csv", dtype="int",delimiter=",")

# %%
# プロット
plt.figure( figsize=(5, 5), dpi=120)
plt.matshow(data, cmap=plt.cm.gray, fignum=1)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# データの読み込み
data = np.genfromtxt("./CA.csv", dtype="int",delimiter=",")

# %%
# データの読み込み
data = np.genfromtxt("./CA.csv", dtype="int",delimiter=",")

# %%
# プロット
plt.figure( figsize=(5, 5), dpi=120)
plt.matshow(data, cmap=plt.cm.gray, fignum=1)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# データの読み込み
data = np.genfromtxt("./CA.csv", dtype="int",delimiter=",")

# %%
# プロット
plt.figure( figsize=(5, 5), dpi=120)
plt.matshow(data, cmap=plt.cm.gray, fignum=1)
plt.show()
